# %% [markdown]
# # Linear Regression with IRIS Flower dataset

# %% [markdown]
# ![Iris_germanica_%28Purple_bearded_Iris%29,_Wakehurst_Place,_UK_-_Diliff.jpg](attachment:Iris_germanica_%28Purple_bearded_Iris%29,_Wakehurst_Place,_UK_-_Diliff.jpg)

# %%
import pandas as pd

# %%
iris=pd.read_csv("C:\\Users\\bhaya\\OneDrive\\Desktop\\Iris.csv")

# %%
iris.head()
# Out:
#      1  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  2.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  3.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  4.0            4.7           3.2            1.3           0.2  Iris-setosa
# 3  5.0            4.6           3.1            1.5           0.2  Iris-setosa
# 4  6.0            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['SepalWidthCm']>4
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: SepalWidthCm, Length: 150, dtype: bool

# %%
iris[iris['SepalWidthCm']>4]
# Out:
#        1  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 15  17.0            5.7           4.4            1.5           0.4
# 32  34.0            5.2           4.1            1.5           0.1
# 33  35.0            5.5           4.2            1.4           0.2
#
#         Species
# 15  Iris-setosa
# 32  Iris-setosa
# 33  Iris-setosa

# %%
iris['PetalWidthCm']>1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146     True
# 147     True
# 148     True
# 149     True
# Name: PetalWidthCm, Length: 150, dtype: bool

# %%
iris[iris['PetalWidthCm']>1]
# Out:
#          1  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50    52.0            7.0           3.2            4.7           1.4
# 51    53.0            6.4           3.2            4.5           1.5
# 52    54.0            6.9           3.1            4.9           1.5
# 53    55.0            5.5           2.3            4.0           1.3
# 54    56.0            6.5           2.8            4.6           1.5
# ..     ...            ...           ...            ...           ...
# 145  147.0            6.7           3.0            5.2           2.3
# 146  148.0            6.3           2.5            5.0           1.9
# 147  149.0            6.5           3.0            5.2           2.0
# 148  150.0            6.2           3.4            5.4           2.3
# 149    NaN            5.9           3.0            5.1           1.8
#
#              Species
# 50   Iris-versicolor
# 51   Iris-versicolor
# 52   Iris-versicolor
# 53   Iris-versicolor
# 54   Iris-versicolor
# ...

# %%
iris['PetalWidthCm']>2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145     True
# 146    False
# 147    False
# 148     True
# 149    False
# Name: PetalWidthCm, Length: 150, dtype: bool

# %%
iris[iris['PetalWidthCm']>2]
# Out:
#          1  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  102.0            6.3           3.3            6.0           2.5
# 102  104.0            7.1           3.0            5.9           2.1
# 104  106.0            6.5           3.0            5.8           2.2
# 105  107.0            7.6           3.0            6.6           2.1
# 109  111.0            7.2           3.6            6.1           2.5
# 112  114.0            6.8           3.0            5.5           2.1
# 114  116.0            5.8           2.8            5.1           2.4
# 115  117.0            6.4           3.2            5.3           2.3
# 117  119.0            7.7           3.8            6.7           2.2
# 118  120.0            7.7           2.6            6.9           2.3
# 120  122.0            6.9           3.2            5.7           2.3
# 124  126.0            6.7           3.3            5.7           2.1
# 128  130.0            6.4           2.8            5.6           2.1
# ...

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris)
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='PetalLengthCm',data=iris,hue='Species')
plt.show()

# %%
iris.head()
# Out:
#      1  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0  2.0            5.1           3.5            1.4           0.2  Iris-setosa
# 1  3.0            4.9           3.0            1.4           0.2  Iris-setosa
# 2  4.0            4.7           3.2            1.3           0.2  Iris-setosa
# 3  5.0            4.6           3.1            1.5           0.2  Iris-setosa
# 4  6.0            5.0           3.6            1.4           0.2  Iris-setosa

# %%
y= iris[['SepalLengthCm']]

# %%
x=iris[['SepalWidthCm']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train.head()
# Out:
#      SepalWidthCm
# 50            3.2
# 123           2.7
# 109           3.6
# 82            2.7
# 10            3.7

# %%
x_test.head()
# Out:
#     SepalWidthCm
# 24           3.4
# 19           3.8
# 68           2.2
# 81           2.4
# 99           2.8

# %%
y_train.head()
# Out:
#      SepalLengthCm
# 50             7.0
# 123            6.3
# 109            7.2
# 82             5.8
# 10             5.4

# %%
y_test.head()
# Out:
#     SepalLengthCm
# 24            4.8
# 19            5.1
# 68            6.2
# 81            5.5
# 99            5.7

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_test.head()
# Out:
#     SepalLengthCm
# 24            4.8
# 19            5.1
# 68            6.2
# 81            5.5
# 99            5.7

# %%
y_pred[0:5]
# Out:
# array([[5.81366144],
#        [5.78498811],
#        [5.89968141],
#        [5.88534475],
#        [5.85667142]])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.8194985606064203

# %%
# model-2

# %%
y=iris[['SepalLengthCm',]]

# %%
x=iris[['SepalWidthCm','PetalLengthCm','PetalWidthCm']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
lr2 = LinearRegression()

# %%
lr2.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr2.predict(x_test)

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 0.10968524776102044
